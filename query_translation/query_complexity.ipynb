# %%
import json
import os
import textstat
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import json
#       2 import os
# ----> 3 import textstat
#
# ModuleNotFoundError: No module named 'textstat'

# %%
json_path_1 = "../data/benchmarks/contractnli.json"
json_path_2 = "../data/sample_benchmarks/contractnli.json"

# %%
with open(json_path_1,'r') as file:
    data1 = json.load(file)
print(len(data1["tests"]))
# Out:
# 977

# %%
with open(json_path_2,"r") as file:
     data2 = json.load(file)
print(data2)
# Out:
# [{'query': 'Consider the Non-Disclosure Agreement between CopAcc and ToP Mentors; Does the document indicate that the Agreement does not grant the Receiving Party any rights to the Confidential Information?', 'snippets': [{'file_path': 'contractnli/CopAcc_NDA-and-ToP-Mentors_2.0_2017.txt', 'span': [11461, 11963], 'answer': 'Any and all proprietary rights, including but not limited to rights to and in inventions, patent rights, utility models, copyrights, trademarks and trade secrets, in and to any Confidential Information shall be and remain with the Participants respectively, and Mentor shall not have any right, license, title or interest in or to any Confidential Information, except the limited right to review, assess and help develop such Confidential Information in connection with the Copernicus Accelerator 2017.'}], 'file_set': ['CopAcc_NDA-and-ToP-Mentors_2.0_2017.txt']}, {'query': 'Consider the Non-Disclosure Agreement between CopAcc and ToP Mentors; Does the document state th
# ...

# %%
#Extracting Queries from both file
queries_file1 = {item['query'] for item in data1["tests"]}
queries_file2 = {item['query'] for item in data2}

# %%
# Queries not in sample data
final_queries = queries_file1 - queries_file2
for query in final_queries:
    print(query)
# Out:
# Consider SINTEC-UK-LTD's Non-Disclosure Agreement; Does the document state that Confidential Information shall only include technical information?
# Consider SWA's Non-Disclosure Agreement; Does the document allow the Receiving Party to share some Confidential Information with third parties, including consultants, agents, and professional advisors?
# Consider the Mutual Non-Disclosure Agreement between AMC and Other Party; Does the document specify whether the Receiving Party is required to destroy or return Confidential Information upon the termination of the Agreement?
# Consider the Mutual Non-Disclosure Agreement between Inventor and Product Development Experts, Inc.; Does the document mention that some obligations of the Agreement may survive the termination of the Agreement?
# Consider Sony Pictures Television's Non-Disclosure Agreement; Does the document allow the Receiving Party to independently develop information that is similar to the Confidential Information?
# ...

# %%
corpus_dir = "../data/corpus/contractnli"

# %%
def load_corpus():
    corpus =[]
    for text_files in os.listdir(corpus_dir):
        file_path = os.path.join(corpus_dir,text_files)
        if os.path.isfile(file_path) and file_path.endswith()
# Out:
#   Cell In[42], line 5
#     if os.path.isfile(file_path) and file_path.endswith()
#                                                          ^
# SyntaxError: invalid syntax

# %%
def calculate_readability(query):
    # Calculate readability scores
    flesch_reading_ease = textstat.flesch_reading_ease(query)
    flesch_kincaid_grade = textstat.flesch_kincaid_grade(query)
    
    return flesch_reading_ease, flesch_kincaid_grade

def classify_readability(flesch_reading_ease, flesch_kincaid_grade):
    # Classify as 'simple' or 'complex' based on the scores
    if flesch_reading_ease > 60 and flesch_kincaid_grade <= 8:
        return "simple"
    else:
        return "complex"

# List of legal queries
queries = [
    "The defendant has committed the act of theft and has been apprehended by law enforcement.",
    "This document outlines the fiduciary duties of corporate directors under the provisions of section 6 of the Companies Act.",
    "What are the requirements for establishing a trust under the law, and how does one go about drafting a trust agreement?"
]

# Create an empty list to store the results
results = []

# Process each query
for query in queries:
    flesch_reading_ease, flesch_kincaid_grade = calculate_readability(query)
    classification = classify_readability(flesch_reading_ease, flesch_kincaid_grade)
    
    # Append the query, scores, and classification to the results
    results.append([query, flesch_reading_ease, flesch_kincaid_grade, classification])

# Convert the results into a DataFrame
df = pd.DataFrame(results, columns=["Query", "Flesch Reading Ease", "Flesch-Kincaid Grade Level", "Classification"])

# Display the DataFrame
print(df)
